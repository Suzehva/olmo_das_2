# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#################################
### CONFIGURE BEFORE YOUR RUN ###
#################################

USER = "aditijb"

# INV_LAYERS = [0, 1, 2, 3, 4, 5, 6, 7, 8]
INV_LAYERS = [0, 1, 2]
INV_DIMS = [8]

# model_id = "suzeva/olmo2-1b-4xH100-2ndtry"
# revision = "step-10000"

model_id = "allenai/OLMo-2-0425-1B"
revision = "main"
# revision = 'stage1-step10000-tokens21B

run_description = 'logits'
EXPERIMENT_NAME = f"year_localization_{model_id.replace('/', '_')}_{revision}_{run_description}" 

prompt_template = ['In {year} there']

# %%
import getpass
import os
import sys

# updated by aditi
FOLDER = f'olmo_das_2/{EXPERIMENT_NAME}'
META_DATA_FOLDER = EXPERIMENT_NAME + "/metadata"

PROJECT_NAME = 'ood-prediction'
DATA_DIR = f'/nlp/scr/{USER}/data'
MODEL_DIR = f'/nlp/scr/{USER}/models'

sys.path.append(f'/nlp/scr/{USER}/{PROJECT_NAME}/src')
os.environ["HF_HOME"] = f'/nlp/scr/{USER}/models'
os.environ["HF_HUB"] = f'/nlp/scr/{USER}/models'

CORE_LIB_DIR = f'/nlp/scr/hij/core'
RAVEL_LIB_DIR = f'/nlp/scr/hij/internal-ravel/src'
PYVENE_LIB_DIR = f'/nlp/scr/hij/pyvene'
import sys
sys.path.append(CORE_LIB_DIR)
sys.path.append(RAVEL_LIB_DIR)
sys.path.append(PYVENE_LIB_DIR)

# %%
import numpy as np
import random
import torch

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(0)

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# # Models

# %%
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer

# SET THE MODEL INFO IN THE TOP CONFIG BLOCK
print("model_id", model_id)
print("revision", revision)

tokenizer = AutoTokenizer.from_pretrained(
    model_id, padding_side='left', revision=revision,
    cache_dir=MODEL_DIR)
tokenizer.pad_token_id = tokenizer.eos_token_id

model = AutoModelForCausalLM.from_pretrained(
      model_id, low_cpu_mem_usage=True, device_map='auto',
      revision=revision,
      torch_dtype=torch.bfloat16, cache_dir=MODEL_DIR)
model = model.eval()
# Out:
# model_id allenai/OLMo-2-0425-1B
# revision main
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# # Behavioral Testing

# %%
# Added by Aditi to store all the config and years info somewhere, for future reference.


import os, json

# make sure folder exists
os.makedirs(META_DATA_FOLDER, exist_ok=True)
print("metadata folder", META_DATA_FOLDER)

# collect config info
config_dict = {
    "prompt_template": prompt_template,
    "FOLDER": FOLDER,
    "META_DATA_FOLDER": META_DATA_FOLDER,
    "PROJECT_NAME": PROJECT_NAME,
    "DATA_DIR": DATA_DIR,
    "MODEL_DIR": MODEL_DIR,
    "model_id": model_id,
    "revision": revision,
    "INV_LAYERS": INV_LAYERS,
    "INV_DIMS": INV_DIMS,    }

# save config
config_file = os.path.join(META_DATA_FOLDER, "config.json")
with open(config_file, "w") as f:
    json.dump(config_dict, f, indent=2)

print(f"Config saved to: {config_file}")
# Out:
# metadata folder year_localization_allenai_OLMo-2-0425-1B_main_logits/metadata
# Config saved to: year_localization_allenai_OLMo-2-0425-1B_main_logits/metadata/config.json

# %%
import json
from generation_utils import generate_distribution_batched

prompts = [prompt_template[0].format(year=year) for year in range(1000, 3000)]
len(prompts)

print("prompt template", prompt_template)
outputs = generate_distribution_batched(model, tokenizer, [prompt_template[0].format(year=i) for i in range(1000, 3000)])

print("first output: ", outputs[0])

# for i in range(1000, 3000):
#     print(i, prompt_template[0].format(year=i), outputs[i-1000])

output_file = f'{META_DATA_FOLDER}/year_{model_id.split("/")[-1]}-revision{revision}_model_next_token_outputs.json'
with open(output_file, 'w') as f:
    json.dump(outputs, f)

# 1001 In 1001, there [(' was', 0.31640625), (' were', 0.296875), (' is', 0.1201171875), (' are', 0.11279296875), (' will', 0.038818359375), ("'s", 0.01953125), (' would', 0.01190185546875), (' had', 0.00982666015625), ('’s', 0.00897216796875), (' have', 0.006561279296875)]
# 1002 In 1002, there [(' was', 0.466796875), (' were', 0.310546875), (' is', 0.09521484375), (' are', 0.0478515625), (' had', 0.010498046875), ("'s", 0.008544921875), (' lived', 0.0037689208984375), (' occurred', 0.0037078857421875), (' came', 0.0036773681640625), (' would', 0.0034942626953125)]
# 1003 In 1003, there [(' was', 0.47265625), (' were', 0.294921875), (' is', 0.10546875), (' are', 0.04736328125), (' had', 0.0111083984375), ("'s", 0.00836181640625), (' lived', 0.0052490234375), (' came', 0.0038299560546875), (' occurred', 0.003631591796875), (' will', 0.0029144287109375)]

# Map specific first words to tense category
word_map = {
    " was": "past",
    " were": "past",
    " is": "presfut",
    " are": "presfut",
    " will": "presfut",
    "was": "past",
    "were": "past",
    "is": "presfut",
    "are": "presfut",
    "will": "presfut",
}

# build year → dict
categorized_outputs = {
    year: {
        "first_word": preds[0][0],
        "category": word_map.get(preds[0][0], "other"),
    }
    for year, preds in zip(range(1000, 3000), outputs)
}

print("categorized_outputs", categorized_outputs)
# Out:
# prompt template ['In {year} there']
# 100%|██████████| 63/63 [00:02<00:00, 30.86it/s]
# first output:  [(' were', 0.73046875), (' was', 0.1015625), (' are', 0.08837890625), (' is', 0.0167236328125), (' will', 0.01129150390625), (' had', 0.0086669921875), (' would', 0.0074462890625), (' have', 0.005035400390625), (' lived', 0.004180908203125), (' has', 0.0025482177734375)]
# categorized_outputs {1000: {'first_word': ' were', 'category': 'past'}, 1001: {'first_word': ' was', 'category': 'past'}, 1002: {'first_word': ' was', 'category': 'past'}, 1003: {'first_word': ' was', 'category': 'past'}, 1004: {'first_word': ' was', 'category': 'past'}, 1005: {'first_word': ' was', 'category': 'past'}, 1006: {'first_word': ' was', 'category': 'past'}, 1007: {'first_word': ' was', 'category': 'past'}, 1008: {'first_word': ' was', 'category': 'past'}, 1009: {'first_word': ' was', 'category': 'past'}, 1010: {'first_word': ' was', 'category': 'past'}, 1011: {'first_word': ' was', 'category': 'past'}, 1012: {'first_word': ' was', 'category': 'past'}, 1013: {'first_word': ' was', 'category': 'past'}, 1014: {'first_word': ' was', 'category': 'past'}, 1015: {'first_word': ' was', 'category': 'past'}, 1016: {'first_word': ' was', 'category': 'past'}, 1017: {'first_word': ' was', 'category': 'past'}, 1018: {'first_word': ' was', 'category': 'past'}, 1019: {'first_word': ' was', 'category': 'past'}, 1020: {'first_word': ' was', 'category': 'past'}, 1021: {'first_word': ' was', 'category': 'past'}, 1022: {'first_word': ' was', 'category': 'past'}, 1023: {'first_word': ' was', 'category': 'past'}, 1024: {'first_word': ' were', 'category': 'past'}, 1025: {'first_word': ' was', 'category': 'past'}, 1026: {'first_word': ' was', 'category': 'past'}, 1027: {'first_word': ' was', 'category': 'past'}, 1028: {'first_word': ' was', 'category': 'past'}, 1029: {'first_word': ' was', 'category': 'past'}, 1030: {'first_word': ' was', 'category': 'past'}, 1031: {'first_word': ' was', 'category': 'past'}, 1032: {'first_word': ' was', 'category': 'past'}, 1033: {'first_word': ' was', 'category': 'past'}, 1034: {'first_word': ' was', 'category': 'past'}, 1035: {'first_word': ' was', 'category': 'past'}, 1036: {'first_word': ' was', 'category': 'past'}, 1037: {'first_word': ' was', 'category': 'past'}, 1038: {'first_word': ' was', 'category': 'past'}, 1039: {'first_word': ' was', 'category': 'past'}, 1040: {'first_word': ' was', 'category': 'past'}, 1041: {'first_word': ' was', 'category': 'past'}, 1042: {'first_word': ' was', 'category': 'past'}, 1043: {'first_word': ' was', 'category': 'past'}, 1044: {'first_word': ' was', 'category': 'past'}, 1045: {'first_word': ' was', 'category': 'past'}, 1046: {'first_word': ' was', 'category': 'past'}, 1047: {'first_word': ' was', 'category': 'past'}, 1048: {'first_word': ' was', 'category': 'past'}, 1049: {'first_word': ' was', 'category': 'past'}, 1050: {'first_word': ' was', 'category': 'past'}, 1051: {'first_word': ' was', 'category': 'past'}, 1052: {'first_word': ' was', 'category': 'past'}, 1053: {'first_word': ' was', 'category': 'past'}, 1054: {'first_word': ' was', 'category': 'past'}, 1055: {'first_word': ' was', 'category': 'past'}, 1056: {'first_word': ' was', 'category': 'past'}, 1057: {'first_word': ' was', 'category': 'past'}, 1058: {'first_word': ' was', 'category': 'past'}, 1059: {'first_word': ' was', 'category': 'past'}, 1060: {'first_word': ' was', 'category': 'past'}, 1061: {'first_word': ' was', 'category': 'past'}, 1062: {'first_word': ' was', 'category': 'past'}, 1063: {'first_word': ' was', 'category': 'past'}, 1064: {'first_word': ' was', 'category': 'past'}, 1065: {'first_word': ' was', 'category': 'past'}, 1066: {'first_word': ' was', 'category': 'past'}, 1067: {'first_word': ' was', 'category': 'past'}, 1068: {'first_word': ' was', 'category': 'past'}, 1069: {'first_word': ' was', 'category': 'past'}, 1070: {'first_word': ' was', 'category': 'past'}, 1071: {'first_word': ' was', 'category': 'past'}, 1072: {'first_word': ' was', 'category': 'past'}, 1073: {'first_word': ' was', 'category': 'past'}, 1074: {'first_word': ' was', 'category': 'past'}, 1075: {'first_word': ' was', 'category': 'past'}, 1076: {'first_word': ' was', 'category': 'past'}, 1077: {'first_word': ' was', 'category': 'past'}, 1078: {'first_word': ' was', 'category': 'past'}, 1079: {'first_word': ' was' ...

# %%
# GOLD DISTRIBUTION

GOLD_YEAR_MAPPING = {
    year: ("past" if year <= 2023 else "presfut")
    for year in range(1000, 3001) if year != 2024
}

print(GOLD_YEAR_MAPPING)
# Out:
# {1000: 'past', 1001: 'past', 1002: 'past', 1003: 'past', 1004: 'past', 1005: 'past', 1006: 'past', 1007: 'past', 1008: 'past', 1009: 'past', 1010: 'past', 1011: 'past', 1012: 'past', 1013: 'past', 1014: 'past', 1015: 'past', 1016: 'past', 1017: 'past', 1018: 'past', 1019: 'past', 1020: 'past', 1021: 'past', 1022: 'past', 1023: 'past', 1024: 'past', 1025: 'past', 1026: 'past', 1027: 'past', 1028: 'past', 1029: 'past', 1030: 'past', 1031: 'past', 1032: 'past', 1033: 'past', 1034: 'past', 1035: 'past', 1036: 'past', 1037: 'past', 1038: 'past', 1039: 'past', 1040: 'past', 1041: 'past', 1042: 'past', 1043: 'past', 1044: 'past', 1045: 'past', 1046: 'past', 1047: 'past', 1048: 'past', 1049: 'past', 1050: 'past', 1051: 'past', 1052: 'past', 1053: 'past', 1054: 'past', 1055: 'past', 1056: 'past', 1057: 'past', 1058: 'past', 1059: 'past', 1060: 'past', 1061: 'past', 1062: 'past', 1063: 'past', 1064: 'past', 1065: 'past', 1066: 'past', 1067: 'past', 1068: 'past', 1069: 'past', 1070: 'past', 1071: 'past', 1072: 'past', 1073: 'past', 1074: 'past', 1075: 'past', 1076: 'past', 1077: 'past', 1078: 'past', 1079: 'past', 1080: 'past', 1081: 'past', 1082: 'past', 1083: 'past', 1084: 'past', 1085: 'past', 1086: 'past', 1087: 'past', 1088: 'past', 1089: 'past', 1090: 'past', 1091: 'past', 1092: 'past', 1093: 'past', 1094: 'past', 1095: 'past', 1096: 'past', 1097: 'past', 1098: 'past', 1099: 'past', 1100: 'past', 1101: 'past', 1102: 'past', 1103: 'past', 1104: 'past', 1105: 'past', 1106: 'past', 1107: 'past', 1108: 'past', 1109: 'past', 1110: 'past', 1111: 'past', 1112: 'past', 1113: 'past', 1114: 'past', 1115: 'past', 1116: 'past', 1117: 'past', 1118: 'past', 1119: 'past', 1120: 'past', 1121: 'past', 1122: 'past', 1123: 'past', 1124: 'past', 1125: 'past', 1126: 'past', 1127: 'past', 1128: 'past', 1129: 'past', 1130: 'past', 1131: 'past', 1132: 'past', 1133: 'past', 1134: 'past', 1135: 'past', 1136: 'past', 1137: 'past', 1138: 'past', 1139: 'past', 1140: 'past', 1141: 'past', 1142: 'past', 1143: 'past', 1144: 'past', 1145: 'past', 1146: 'past', 1147: 'past', 1148: 'past', 1149: 'past', 1150: 'past', 1151: 'past', 1152: 'past', 1153: 'past', 1154: 'past', 1155: 'past', 1156: 'past', 1157: 'past', 1158: 'past', 1159: 'past', 1160: 'past', 1161: 'past', 1162: 'past', 1163: 'past', 1164: 'past', 1165: 'past', 1166: 'past', 1167: 'past', 1168: 'past', 1169: 'past', 1170: 'past', 1171: 'past', 1172: 'past', 1173: 'past', 1174: 'past', 1175: 'past', 1176: 'past', 1177: 'past', 1178: 'past', 1179: 'past', 1180: 'past', 1181: 'past', 1182: 'past', 1183: 'past', 1184: 'past', 1185: 'past', 1186: 'past', 1187: 'past', 1188: 'past', 1189: 'past', 1190: 'past', 1191: 'past', 1192: 'past', 1193: 'past', 1194: 'past', 1195: 'past', 1196: 'past', 1197: 'past', 1198: 'past', 1199: 'past', 1200: 'past', 1201: 'past', 1202: 'past', 1203: 'past', 1204: 'past', 1205: 'past', 1206: 'past', 1207: 'past', 1208: 'past', 1209: 'past', 1210: 'past', 1211: 'past', 1212: 'past', 1213: 'past', 1214: 'past', 1215: 'past', 1216: 'past', 1217: 'past', 1218: 'past', 1219: 'past', 1220: 'past', 1221: 'past', 1222: 'past', 1223: 'past', 1224: 'past', 1225: 'past', 1226: 'past', 1227: 'past', 1228: 'past', 1229: 'past', 1230: 'past', 1231: 'past', 1232: 'past', 1233: 'past', 1234: 'past', 1235: 'past', 1236: 'past', 1237: 'past', 1238: 'past', 1239: 'past', 1240: 'past', 1241: 'past', 1242: 'past', 1243: 'past', 1244: 'past', 1245: 'past', 1246: 'past', 1247: 'past', 1248: 'past', 1249: 'past', 1250: 'past', 1251: 'past', 1252: 'past', 1253: 'past', 1254: 'past', 1255: 'past', 1256: 'past', 1257: 'past', 1258: 'past', 1259: 'past', 1260: 'past', 1261: 'past', 1262: 'past', 1263: 'past', 1264: 'past', 1265: 'past', 1266: 'past', 1267: 'past', 1268: 'past', 1269: 'past', 1270: 'past', 1271: 'past', 1272: 'past', 1273: 'past', 1274: 'past', 1275: 'past', 1276: 'past', 1277: 'past', 1278: 'past', 1279: 'past', 1280: 'past', 1281: 'past', 1282: 'past', 1283: 'past', 1284: 'past', 1285: 'pa ...

# %%
# Filter the years down to those where the gold year label (from your GOLD_YEAR_MAPPING) matches the category of the top predicted verb (from categorized_outputs).

matching_years = [
    year
    for year in range(1000, 3000)
    if GOLD_YEAR_MAPPING.get(year) == categorized_outputs[year]["category"]
]

past_years = [year for year in matching_years if categorized_outputs[year]["category"] == "past"]
presfut_years = [year for year in matching_years if categorized_outputs[year]["category"] == "presfut"]

print("matching_years\n", matching_years)
print("past_years\n", len(past_years), past_years)
print("presfut_years\n", len(presfut_years), presfut_years)
# Out:
# matching_years
#  [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 16 ...
# past_years
#  1023 [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 166 ...
# presfut_years
#  40 [2025, 2026, 2028, 2029, 2030, 2035, 2038, 2039, 2040, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2070, 2077, 2080, 2081, 2084, 2099, 2100, 2106, 2109, 2199, 2300, 2400, 2500, 2640, 2666, 2700, 2900]
